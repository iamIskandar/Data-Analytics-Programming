# %% [markdown]
# ### Simple Challenge 4
#
# In pandas library, you can read CSV data file using the ```read_csv``` function in pandas. The function will read the csv data file straight into data frame, with the default setting where 1st row of the data file will become the header of the data frame.

# %%
import pandas as pd

data = pd.read_csv('telco-customer-churn.csv')
data[:]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
# TASK 1
newFrame=data.loc[((data['SeniorCitizen'])&(data['tenure']>12))]
newFrame
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 30    3841-NFECX  Female              1     Yes         No      71
# 50    8012-SOUDQ  Female              1      No         No      43
# 52    6575-SUVOI  Female              1     Yes         No      25
# 54    4667-QONEA  Female              1     Yes        Yes      60
# 55    1658-BYGOY    Male              1      No         No      18
# ...          ...     ...            ...     ...        ...     ...
# 6993  6583-QGCSI  Female              1     Yes         No      50
# 7007  2274-XUATA    Male              1     Yes         No      72
# 7015  0666-UXTJO    Male              1     Yes         No      34
# 7023  1035-IPQPU  Female              1     Yes         No      63
# 7031  3605-JISKB    Male              1     Yes         No      55
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 30            Yes               Yes     Fiber optic            Yes  ...
# ...

# %%
# TASK 2
churned=data.loc[data['Churn']=='Yes']
churned
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2     3668-QPYBK    Male              0      No         No       2
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 8     7892-POOKP  Female              0     Yes         No      28
# 13    0280-XJGEX    Male              0      No         No      49
# ...          ...     ...            ...     ...        ...     ...
# 7021  1699-HPSBG    Male              0      No         No      12
# 7026  8775-CEBBJ  Female              0      No         No       9
# 7032  6894-LFHLY    Male              1      No         No       1
# 7034  0639-TSIQW  Female              0      No         No      67
# 7041  8361-LTMKD    Male              1     Yes         No       4
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 2             Yes            No             DSL            Yes  ...
# ...

# %%
churned['tenure'].max()
# Out:
# 72

# %%
churned['tenure'].min()
# Out:
# 1

# %%
churned['customerID'].count()
# Out:
# 1869

# %%
churned['tenure'].mean()
# Out:
# 17.979133226324237

# %%
newFrame.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
newFrame_2=data.loc[data['tenure']>12]
newFrame_2
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1     5575-GNVDE    Male              0      No         No      34
# 3     7795-CFOCW    Male              0      No         No      45
# 6     1452-KIOVK    Male              0      No        Yes      22
# 8     7892-POOKP  Female              0     Yes         No      28
# 9     6388-TABGU    Male              0      No        Yes      62
# ...          ...     ...            ...     ...        ...     ...
# 7035  8456-QDAVC    Male              0      No         No      19
# 7037  2569-WGERO  Female              0      No         No      72
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 1             Yes                No             DSL                  Yes  ...
# ...

# %%
newFrame_2=pd.DataFrame(newFrame_2, columns=['customerID','Churn','InternetService','StreamingTV','tenure','Contract','MonthlyCharges'])
newFrane_2=newFrame_2.sort_values(['tenure','MonthlyCharges'],ascending=[True,False])
newFrame_2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-281cbee41f2a> in <module>
#       1 newFrame_2=pd.DataFrame(newFrame_2, columns=['customerID','Churn','InternetService','StreamingTV','tenure','Contract','MonthlyCharges'])
# ----> 2 newFrane_2=newFrame_2.sort(['tenure','MonthlyCharges'],ascending=[True,False])
#       3 newFrame_2
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sort'
